# %%
from utils.utils import show_image, show_and_get_tables, get_table_data
from img2table.document import Image

# %%
show_image("resources/images/6.png")

# %%
from img2table.document import Image
from img2table.ocr import TesseractOCR
import pandas as pd

iamge = Image(src="resources/images/6.png")

ocr = TesseractOCR(lang="rus")

iamge.to_xlsx('results/img2table/tables_1.xlsx', ocr=ocr)

df = pd.read_excel("results/img2table/tables_1.xlsx")

df
# Out:
#     »            Unnamed: 1                          Требования п рекомендации
# 0 NaN                   NaN                    В идеале: Тнпез 14. Отступления
# 1 NaN                   NaN  Межстрочный интервал 1,3-1,5. Красная строка а...
# 2 NaN             "Страница  Левое поле не менее 2 см. Страницы нумеруются,...
# 3 NaN             Структура  Нумерация всех объектов (разделов, рисунков, т...
# 4 NaN  Заголовки:\nразделов  В заголовках разделов не должно быть сокращени...

# %%
res = get_table_data("resources/images/6.png")

res[0]
# Out:
#    0                    1                                                  2
# 0  №              Область                         Требования и рекомендации.
# 1  1               Шрифт.  В идеале: City of Cathay 14. Отступления возмо...
# 2  2               Абзац.  Межстрочный интервал — 1,3–1,5. Красная строка...
# 3  3             Страница  Левое поле, не менее 2 см. Страницы нумеруются...
# 4  4            Структура  Нумерация всех объектов (разделов, рисунков, т...
# 5  5  Заголовки разделов:  В заголовках разделов не должно быть сокращени...

# %%
from img2table.document import Image
from img2table.ocr import TesseractOCR
import pandas as pd

iamge = Image(src="resources/images/4.jpg")

ocr = TesseractOCR(lang="eng")

iamge.to_xlsx('results/img2table/tables_1.xlsx', ocr=ocr)

df = pd.read_excel("results/img2table/tables_1.xlsx")

df
# Out:
#    ID     Name  Age            City
# 0 NaN    Alice   30        New York
# 1 NaN      Bob   25  ‘San Francisco
# 2 NaN  Charlie   35     Los Angeles
# 3 NaN    Diana   28         Chicago
